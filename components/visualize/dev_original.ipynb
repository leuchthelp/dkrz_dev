# %%
#%%script false --no-raise-error
import pandas as pd

#df1 = pd.read_json("/home/dev/dkrz_dev/components/visualize/plotting/plotting_bench_python_parallel.json")
#print(df1)

df_new = pd.read_json("/home/dev/dkrz_dev/components/visualize/results.json")
#print(df_new)

# %%
import plotly.express as px 

show_parallel = False

df_list = []

if show_parallel is True:
    df_list = [d for _, d in df_new[df_new["parallel"] == True].groupby(["ranks"])]
else:
    df_list.append(df_new[df_new["parallel"] == False])



for df_ranks in df_list:
    
    ranks = df_ranks["ranks"].iat[0]

    fig = px.line(
        data_frame=df_ranks, 
        log_y=True, 
        x="total filesize", 
        y="mean time", 
        color="engine", 
        markers=True, 
        hover_data=["format"], 
        labels={"mean time": f"mean time in seconds (s) for {ranks} ranks"},
        error_y="error bar", 
        color_discrete_map={
            "zarr-py-False": '#56B4E9',
            "netcdf4-py-False": '#4B0092',
            "hdf5-py-False": '#117733',
            "zarr-py-True": '#AB029E',
            "netcdf4-py-True": '#FFB000',
            "hdf5-py-True": '#FF4430',
        },
        )

    fig.show()

    unit = df_new["unit"].iat[0]
    fig = px.bar(
        data_frame=df_ranks.drop_duplicates(subset=['throughput']), 
        x="total filesize", 
        y="throughput", 
        color="engine", 
        barmode='group', 
        hover_data=["format"], 
        labels={"throughput": f"throughput in {unit}/s for {ranks} ranks"},
        color_discrete_map={
            "zarr-py-False": '#56B4E9',
            "netcdf4-py-False": '#4B0092',
            "hdf5-py-False": '#117733',
            "zarr-py-True": '#AB029E',
            "netcdf4-py-True": '#FFB000',
            "hdf5-py-True": '#FF4430',
        },
        )

    fig.show()
    
df_test = df_list[0]
# Out:
# <div>                            <div id="a97889a8-a568-4463-a72f-8ec6e7af5556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a97889a8-a568-4463-a72f-8ec6e7af5556")) {                    Plotly.newPlot(                        "a97889a8-a568-4463-a72f-8ec6e7af5556",                        [{"customdata":[["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5" ...
# <div>                            <div id="0aa98ec6-3894-4284-b275-ddbcae5045e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0aa98ec6-3894-4284-b275-ddbcae5045e8")) {                    Plotly.newPlot(                        "0aa98ec6-3894-4284-b275-ddbcae5045e8",                        [{"alignmentgroup":"True","customdata":[["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"],["hdf5"]],"hovertemplate":"engine=hdf5-py-False\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs for 8 ranks=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-py-False","marker":{"color":"#117733","pattern":{"shape":""}},"name":"hdf5-py-False","offsetgroup":"hdf5-py-False","orientation":"v","showlegend":true,"textposition":"auto","x":[10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,50,50,50,50,60,60,60,60,70,70,70,70,80,80,80,80,90,90,90,90,100,100,100,100],"xaxis":"x","y":[1.0016056279,0.9702412661,1.0296496234,1.0319864543,0.9198119069,0.9362706725000001,0.9443864519,0.9360877044,0.9351128503,0.9243314253,0.46335062530000004,0.4961944039,0.7177696421,0.17618608130000002,0.3994450342,0.2576545074,0.2790284565,0.5588230551,0.3307576425,0.26847211990000003,0.8295754154,0.6610308669,0.1487729129,0.6985440753000001,0.3616020021,0.8845325005,0.30011832850000003,0.3775398432,0.4447584343,0.8477451588,0.2574286,0.27122278780000003,0.21355214930000002,0.3893490941,0.8592429027,0.1675277045,0.4334486114,0.3026501916,0.6541431672,0.34643251210000003],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"],["netcdf4"]],"hovertemplate":"engine=netcdf4-py-False\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs for 8 ranks=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-py-False","marker":{"color":"#4B0092","pattern":{"shape":""}},"name":"netcdf4-py-False","offsetgroup":"netcdf4-py-False","orientation":"v","showlegend":true,"textposition":"auto","x":[10,10,10,10,20,20,20,20,30,30,30,30,40,40,40,40,50,50,50,50,60,60,60,60,70,70,70,70,80,80,80,80,90,90,90,90,100,100,100,100],"xaxis":"x","y":[0.8997536123000001,0.8997823304,0.8769033788,0.9120309688,0.8644591322,0.8581160284,0.8451523714,0.8682231417,0.6671591144,0.86402047,0.8611116648,0.8661835520000001,0.5783202732,0.2827786225,0.36445093500000003,0.22431789030000002,0.38091951,0.35907136840000003,0.3469813726,0.3302332471,0.2627772974,0.3678079721,0.3459851735,0.31849279540000003,0.35686917,0.3876016868,0.2538606108,0.6794018392000001,0.29053000290000003,0.4690156791,0.5938275747,0.3815231626,0.5999112828000001,0.5466017980000001,0.7435717905,0.5110337692,0.4692793792,0.6414190270000001,0.6786809205000001,0.3502068772],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"],["zarr"], ...

# %%
import numpy as np

x = [437.620, 468.010, 463.439]

mean = np.mean(x)

y = []
for value in x:
    y.append(value - mean)

std_div = np.std(y)

print(x)
print(mean)
print(y)
print(std_div)

print(f"rsd: {(std_div / mean):.2%}")
# Out:
# [437.62, 468.01, 463.439]
# 456.35633333333334
# [np.float64(-18.736333333333334), np.float64(11.653666666666652), np.float64(7.082666666666682)]
# 13.379365962389828
# rsd: 2.93%

# %%
import numpy as np

x = [23.117, 22.511, 22.637, 22.260, 22.333]

mean = np.mean(x)

y = []
for value in x:
    y.append(value - mean)

std_div = np.std(x)

print(x)
print(mean)
print(y)
print(std_div)

x = [53.259, 51.949, 53.838, 53.082, 51.183]

mean = np.mean(x)

y = []
for value in x:
    y.append(value - mean)

std_div = np.std(x)

print(x)
print(mean)
print(y)
print(std_div)
# Out:
# [23.117, 22.511, 22.637, 22.26, 22.333]
# 22.5716
# [np.float64(0.5454000000000008), np.float64(-0.060600000000000875), np.float64(0.06540000000000035), np.float64(-0.31159999999999854), np.float64(-0.2386000000000017)]
# 0.3031287515231773
# [53.259, 51.949, 53.838, 53.082, 51.183]
# 52.6622
# [np.float64(0.5968000000000018), np.float64(-0.7132000000000005), np.float64(1.1758000000000024), np.float64(0.41980000000000217), np.float64(-1.4791999999999987)]
# 0.9603743853310548

# %%
print(f"improved by: {(1- 9 / 10.75):.2%}")
# Out:
# improved by: 16.28%

# %%
import pandas as pd
import numpy as np

df = pd.read_json("data/plotting/plotting_bench_python.json")


df = df[df["engine"].isin(["netcdf4-python-parallel", "hdf5-python-parallel"])]

#df = df[~df["engine"].isin(["netcdf4-python", "hdf5-python", "zarr-python"])]

#df = df[~df["total filesize"].isin(["30.0 GB", "40.0 GB", "50.0 GB", "60.0 GB", "70.0 GB"])]

#df = df[~(df["engine"].isin(["netcdf4-python"])) | (df["total filesize"].isin(["10.0 GB", "20.0 GB", "30.0 GB", "40.0 GB"]))]
#df = df[~(df["engine"].isin(["hdf5-python"])) | (df["total filesize"].isin(["10.0 GB", "20.0 GB", "70.0 GB"]))]

#df = df[df["total filesize"].isin(["10.0 GB", "20.0 GB", "30.0 GB", "40.0 GB"])]
#df = df[df["total filesize"].isin(["10.0 GB", "20.0 GB", "70.0 GB"])]

res = {}
res2 = []
col_mean_seq = []
col_mean_par = []
throu_seq = []
throu_par = []
format1 = []
format2 = []
format3 = []
format4 = []

filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    std_div =  np.std(df_format["time taken"].to_list())
    mean =  np.mean(df_format["time taken"].to_list())
    
    
    #print(f"std_div: {std_div} and mean: {mean} for format {format}")
    
    rsd = std_div / mean
    
    res[format] = f"{rsd:.2%}"
    
    #df_format["engine"].iat[0] == "netcdf4-python" or  df_format["engine"].iat[0] == "hdf5-python" or df_format["engine"].iat[0] == "zarr-python"
    
    if df_format["engine"].iat[0] == "netcdf4-python-parallel":
        col_mean_seq.append(mean)
        format1.append(format)
    else:
        col_mean_par.append(mean)
        format2.append(format)
        
    res2.append(rsd)
    
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])

    throughput = filesize / mean
    
    if df_format["engine"].iat[0] == "netcdf4-python-parallel":
        throu_seq.append(throughput)
        format3.append(format)
    else:
        throu_par.append(throughput)
        format4.append(format)
    
    
    #print(f"rsd: {np.round(rsd, decimals=3)}%")
    
#print(col_mean)
#print(f"sequential means: {col_mean_seq} \nformat: {format1} \n")
#print(f"parallel means: {col_mean_par} \nformat: {format2} \n")

mean = np.ndarray(shape=2)
mean[0] = np.mean(col_mean_seq)
mean[1] = np.mean(col_mean_par)

#print(mean)

print(f"mean-time: {mean.min()} is faster than {mean.max()} by: {(1- mean.min() / mean.max()):.02%}")

print(f"mean-time: {mean.max()} is {(mean.max() / mean.min()):.3}x slower than {mean.min()}")

#print(f"sequential throughput: {throu_seq} \nformat: {format3} \n")
#print(f"parallel throughput: {throu_par} \nformat: {format4} \n")

tmean = np.ndarray(shape=2)
tmean[0] = np.mean(throu_seq)
tmean[1] = np.mean(throu_par)

#print(tmean)

print(f"throughput: {tmean.max()} is higher than {tmean.min()} by: {(tmean.max() / tmean.min() - 1):.02%}")

print(f"throughput: {tmean.max()} is {(tmean.max() / tmean.min()):.3}x ahead of {tmean.min()}")

# %%
import pandas as pd
import numpy as np

df = pd.read_json("data/plotting/plotting_bench_c.json")

#df = df[~df["engine"].isin(["hdf5-subfiling"])]
df = df[df["engine"].isin(["hdf5-c", "netcdf4-c"])]
#df = df[~df["total filesize"].isin(["20.0 GB"])]

#df = df[~df["total filesize"].isin(["30.0 GB", "40.0 GB", "50.0 GB", "60.0 GB", "70.0 GB"])]

#df = df[~(df["engine"].isin(["netcdf4-c"])) | ~(df["total filesize"].isin(["30.0 GB", "40.0 GB", "60.0 GB", "70.0 GB"]))]
#df = df[~(df["engine"].isin(["hdf5-python"])) | (df["total filesize"].isin(["10.0 GB", "20.0 GB", "70.0 GB"]))]

df = df[~df["total filesize"].isin(["30.0 GB", "40.0 GB", "60.0 GB", "70.0 GB"])]
#df = df[df["total filesize"].isin(["10.0 GB", "20.0 GB", "70.0 GB"])]

res = {}
res2 = []
col_mean_seq = []
col_mean_par = []
throu_seq = []
throu_par = []
format1 = []
format2 = []
format3 = []
format4 = []

filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    std_div =  np.std(df_format["time taken"].to_list())
    mean =  np.mean(df_format["time taken"].to_list())
    
    
    #print(f"std_div: {std_div} and mean: {mean} for format {format}")
    
    rsd = std_div / mean
    
    res[format] = f"{rsd:.2%}"
    
    #df_format["engine"].iat[0] == "netcdf4-python" or  df_format["engine"].iat[0] == "hdf5-python" or df_format["engine"].iat[0] == "zarr-python"
    
    if df_format["engine"].iat[0] == "netcdf4-c":
        col_mean_seq.append(mean)
        format1.append(format)
    else:
        col_mean_par.append(mean)
        format2.append(format)
        
    res2.append(rsd)
    
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])

    throughput = filesize / mean
    
    if df_format["engine"].iat[0] == "netcdf4-c":
        throu_seq.append(throughput)
        format3.append(format)
    else:
        throu_par.append(throughput)
        format4.append(format)
    
    
    #print(f"rsd: {np.round(rsd, decimals=3)}%")
    
#print(col_mean)
#print(f"sequential means: {col_mean_seq} \nformat: {format1} \n")
#print(f"parallel means: {col_mean_par} \nformat: {format2} \n")

mean = np.ndarray(shape=2)
mean[0] = np.mean(col_mean_seq)
mean[1] = np.mean(col_mean_par)

#print(mean)

print(f"mean-time: {mean.min()} is faster than {mean.max()} by: {(1- mean.min() / mean.max()):.02%}")

print(f"mean-time: {mean.max()} is {(mean.max() / mean.min()):.3}x slower than {mean.min()}")

#print(f"sequential throughput: {throu_seq} \nformat: {format3} \n")
#print(f"parallel throughput: {throu_par} \nformat: {format4} \n")

tmean = np.ndarray(shape=2)
tmean[0] = np.mean(throu_seq)
tmean[1] = np.mean(throu_par)

#print(tmean)

print(f"throughput: {tmean.max()} is higher than {tmean.min()} by: {((tmean.max() / tmean.min()) - 1):.02%}")

print(f"throughput: {tmean.max()} is {(tmean.max() / tmean.min()):.3}x ahead of {tmean.min()}")
# Out:
# mean-time: 18.05403086666667 is faster than 41.00133686666667 by: 55.97%
# mean-time: 41.00133686666667 is 2.27x slower than 18.05403086666667
# throughput: 1.5876156427219448 is higher than 0.6986463265601898 by: 127.24%
# throughput: 1.5876156427219448 is 2.27x ahead of 0.6986463265601898

# %%
import pandas as pd
import numpy as np

df = pd.read_json("data/plotting/plotting_bench_python.json")
df2 = pd.read_json("data/plotting/plotting_bench_c.json")

df = pd.concat([df, df2], ignore_index=True)

#df = df[~df["engine"].isin(["netcdf4-python", "hdf5-python", "zarr-python", "netcdf4-c", "hdf5-c", "hdf5-subfiling"])]
#df = df[df["engine"].isin(["zarr-python", "hdf5-c"])]
df = df[df["engine"].isin(["netcdf4-python-parallel", "hdf5-c-parallel"])]

res = {}
res2 = []
col_mean_seq = []
col_mean_par = []
throu_seq = []
throu_par = []
format1 = []
format2 = []
format3 = []
format4 = []

filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    std_div =  np.std(df_format["time taken"].to_list())
    mean =  np.mean(df_format["time taken"].to_list())
    
    
    #print(f"std_div: {std_div} and mean: {mean} for format {format}")
    
    rsd = std_div / mean
    
    res[format] = f"{rsd:.2%}"
    
    #df_format["engine"].iat[0] == "netcdf4-python" or  df_format["engine"].iat[0] == "hdf5-python" or df_format["engine"].iat[0] == "zarr-python"
    
    if df_format["engine"].iat[0] == "netcdf4-python-parallel":
        col_mean_seq.append(mean)
        format1.append(format)
    else:
        col_mean_par.append(mean)
        format2.append(format)
        
    res2.append(rsd)
    
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])

    throughput = filesize / mean
    
    if df_format["engine"].iat[0] == "netcdf4-python-parallel":
        throu_seq.append(throughput)
        format3.append(format)
    else:
        throu_par.append(throughput)
        format4.append(format)
    
    
    #print(f"rsd: {np.round(rsd, decimals=3)}%")
    
#print(col_mean)
#print(f"sequential means: {col_mean_seq} \nformat: {format1} \n")
#print(f"parallel means: {col_mean_par} \nformat: {format2} \n")

mean = np.ndarray(shape=2)
mean[0] = np.mean(col_mean_seq)
mean[1] = np.mean(col_mean_par)

#print(mean)

print(f"mean-time: {mean.min()} is faster than {mean.max()} by: {(1- mean.min() / mean.max()):.02%}")

print(f"mean-time: {mean.max()} is {(mean.max() / mean.min()):.3}x slower than {mean.min()}")

#print(f"sequential throughput: {throu_seq} \nformat: {format3} \n")
#print(f"parallel throughput: {throu_par} \nformat: {format4} \n")

tmean = np.ndarray(shape=2)
tmean[0] = np.mean(throu_seq)
tmean[1] = np.mean(throu_par)

#print(tmean)

print(f"throughput: {tmean.max()} is higher than {tmean.min()} by: {(tmean.max() / tmean.min() - 1):.02%}")

print(f"throughput: {tmean.max()} is {(tmean.max() / tmean.min()):.3}x ahead of {tmean.min()}")
# Out:
# mean-time: 8.897380865125715 is faster than 13.753472142857143 by: 35.31%
# mean-time: 13.753472142857143 is 1.55x slower than 8.897380865125715
# throughput: 4.770756788661214 is higher than 3.4064292506189657 by: 40.05%
# throughput: 4.770756788661214 is 1.4x ahead of 3.4064292506189657

# %%
import pandas as pd
import numpy as np

df = pd.read_json("/home/dev/dkrz_dev/components/visualize/plotting/plotting_bench_python_parallel.json")

df = df[~df["engine"].isin(["netcdf4-python", "hdf5-python", "zarr-python"])]

res = {}
res2 = []

filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    std_div =  np.std(df_format["time taken"].to_list())
    mean =  np.mean(df_format["time taken"].to_list())
    
    
    #print(f"std_div: {std_div} and mean: {mean} for format {format}")
    
    rsd = std_div / mean
    
    res[format] = f"{rsd:.2%}"
    res2.append(rsd)
    
    
    #print(f"rsd: {np.round(rsd, decimals=3)}%")
    
print(res)
#print(res2)
# Out:
# {'netcdf4-python-parallel-[1342177280]-[]': '21.43%', 'hdf5-python-parallel-[1342177280]-[]': '19.12%', 'netcdf4-python-parallel-[2684354560]-[]': '19.48%', 'hdf5-python-parallel-[2684354560]-[]': '20.06%', 'netcdf4-python-parallel-[4026531840]-[]': '16.88%', 'hdf5-python-parallel-[4026531840]-[]': '24.26%', 'netcdf4-python-parallel-[5368709120]-[]': '19.85%', 'hdf5-python-parallel-[5368709120]-[]': '18.83%', 'netcdf4-python-parallel-[6710886400]-[]': '27.79%', 'hdf5-python-parallel-[6710886400]-[]': '23.50%', 'netcdf4-python-parallel-[8053063680]-[]': '26.15%', 'hdf5-python-parallel-[8053063680]-[]': '16.53%'}

# %%
#%%script false --no-raise-error
import pandas as pd

df_bench_c = pd.read_json("/home/dev/dkrz_dev/components/visualize/plotting/plotting_bench_c.json")
df_bench_c_copy = pd.read_json("/home/dev/dkrz_dev/components/visualize/plotting/plotting_bench_c copy.json")
df_bench_python = pd.read_json("/home/dev/dkrz_dev/components/visualize/plotting/plotting_bench_python.json")
df_bench_python_copy = pd.read_json("/home/dev/dkrz_dev/components/visualize/plotting/plotting_bench_python copy.json")

# %%
import plotly.express as px 
import numpy as np
from scipy import stats

df = df_bench_python

save_image = False

# python plotting

# plot development in time taken by chunksize

#df = df[~df["engine"].isin(["netcdf4-python-parallel", "hdf5-python-parallel"])]

filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    mean =  np.mean(df_format["time taken"].to_list())
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])
    unit = f"{str_filesize.split()[1]}/s"

    throughput = filesize / mean
    
    error = stats.sem(df_format["time taken"].to_list())
    
    tmp = pd.DataFrame(data=[{"error bar": error, "time taken": df_format["time taken"], "mean time": mean, "format": format, "engine": df_format["engine"].iat[0], "run": df_format["run"].iat[0], "total filesize": df_format["total filesize"].iat[0], "throughput": throughput, "unit":unit}])
    smth = pd.concat([smth, tmp], ignore_index=True)

fig = px.line(
    data_frame=smth, 
    log_y=True, 
    x="total filesize", 
    y="mean time", 
    color="engine", 
    markers=True, 
    hover_data=["format"], 
    labels={"mean time": "mean time in seconds (s)"},
    error_y="error bar",
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-python-parallel": '#FFB000',
        "hdf5-python-parallel": '#FF4430',
    },
    )

fig.show()
if save_image: fig.write_image("images/python-line-total-filesize.svg", width=900, height=500, scale=1)

unit = smth["unit"].iat[0]
fig = px.bar(
    data_frame=smth, 
    x="total filesize", 
    y="throughput", 
    color="engine", 
    barmode='group', 
    hover_data=["format"], 
    labels={"throughput": f"throughput in {unit}"},
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-python-parallel": '#FFB000',
        "hdf5-python-parallel": '#FF4430',
    },
    )

fig.show()
if save_image: fig.write_image("images/python-box-datarate.svg", width=900, height=500, scale=1)



save_image = False


filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    std_div =  np.std(df_format["time taken"].to_list())
    mean =  np.mean(df_format["time taken"].to_list())
    
    rsd = std_div / mean
    
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])
    unit = f"{str_filesize.split()[1]}/s"

    throughput = filesize / mean
    
    tmp = pd.DataFrame(data=[{"mean time": mean, "format": format, "engine": df_format["engine"].iat[0], "run": df_format["run"].iat[0], "total filesize": df_format["total filesize"].iat[0], "throughput": throughput, "unit": unit, "relative standard deviation": f"{rsd:.2%}"}])
    smth = pd.concat([smth, tmp], ignore_index=True)
    
#smth = smth[~smth["engine"].isin(["netcdf4-python", "hdf5-python", "zarr-python"])]
#smth = smth[~smth["total filesize"].isin(["50.0 GB", "60.0 GB", "70.0 GB"])]

#smth = smth[~(smth["engine"].isin(["netcdf4-python"])) | (smth["total filesize"].isin(["10.0 GB", "20.0 GB", "30.0 GB", "40.0 GB"]))]
#smth = smth[~(smth["engine"].isin(["hdf5-python"])) | (smth["total filesize"].isin(["10.0 GB", "20.0 GB", "70.0 GB"]))]

fig = px.box(
    data_frame=smth,
    log_y=True,
    x="engine",  
    y="relative standard deviation", 
    color="engine", 
    hover_data=["format"], 
    labels={"relative standard deviation": "relative standard deviation (%)"},
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-python-parallel": '#FFB000',
        "hdf5-python-parallel": '#FF4430',
    },
    )
fig.update_traces(boxmean=True, showlegend=True)
fig.add_shape(name="mean", visible='legendonly', showlegend=True, type="line", line=dict(dash="3px"))
fig.show()

if save_image: fig.write_image("images/rsd-parallel.svg", width=900, height=500, scale=1)

smth = df
#smth = smth[~smth["engine"].isin(["zarr-python", "netcdf4-python-parallel", "hdf5-python-parallel"])]
#smth = smth[~smth["total filesize"].isin(["20.0 GB", "30.0 GB", "40.0 GB", "50.0 GB", "60.0 GB", "70.0 GB"])]

fig = px.box(
    data_frame=smth,
    log_y=True, 
    x="total filesize", 
    y="time taken", 
    color="engine",  
    hover_data=["format"], 
    labels={"time taken": "time taken in seconds (s)"},
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-python-parallel": '#FFB000',
        "hdf5-python-parallel": '#FF4430',
    },
    )
fig.update_traces(boxmean=True, showlegend=True)
fig.add_shape(name="mean", visible='legendonly', showlegend=True, type="line", line=dict(dash="3px"))
fig.show()
    


#################################################################################################################################################################################
#################################################################################################################################################################################
#################################################################################################################################################################################
#################################################################################################################################################################################
#################################################################################################################################################################################


df = df_bench_c_copy

# c plotting

save_image = False

#df = df[~df["engine"].isin(["netcdf4-c", "hdf5-c"])]

#df = df[df["engine"].isin(["netcdf4-c"])]
#df = df[df["engine"].isin(["hdf5-subfiling"])]

# plot development in time taken by chunksize
filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    mean =  np.mean(df_format["time taken"].to_list())
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])
    unit = f"{str_filesize.split()[1]}/s"

    throughput = filesize / mean
    
    error = stats.sem(df_format["time taken"].to_list())
    
    tmp = pd.DataFrame(data=[{"error bar": error, "mean time": mean, "format": format, "engine": df_format["engine"].iat[0], "run": df_format["run"].iat[0], "total filesize": df_format["total filesize"].iat[0], "throughput": throughput, "unit":unit}])
    smth = pd.concat([smth, tmp], ignore_index=True)

fig = px.line(
    data_frame=smth, 
    log_y=True, 
    x="total filesize", 
    y="mean time", 
    color="engine", 
    markers=True, 
    hover_data=["format"], 
    labels={"mean time": "mean time in seconds (s)"},
    error_y="error bar",
    color_discrete_map={
        "netcdf4-c": '#4B0092',
        "hdf5-c": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )

fig.show()
if save_image: fig.write_image("images/c-netcdf4.svg", width=900, height=500, scale=1)

unit = smth["unit"].iat[0]
fig = px.bar(
    data_frame=smth, 
    x="total filesize", 
    y="throughput", 
    color="engine", 
    barmode='group', 
    hover_data=["format"], 
    labels={"throughput": f"throughput in {unit}"},
    color_discrete_map={
        "netcdf4-c": '#4B0092',
        "hdf5-c": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )
fig.show()
#if save_image: fig.write_image("images/c-box-datarate-par.svg", width=900, height=500, scale=1)


save_image = False

df = pd.concat([df_bench_python, df_bench_c], ignore_index=True)

# plotting both

df = df[~df["engine"].isin(["netcdf4-python", "hdf5-python", "zarr-python", "netcdf4-c", "hdf5-c"])]
#df = df[~df["total filesize"].isin(["40.0 GB", "50.0 GB", "60.0 GB", "70.0 GB"])]

# plot development in time taken by chunksize
filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    mean =  np.mean(df_format["time taken"].to_list())
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])
    unit = f"{str_filesize.split()[1]}/s"

    throughput = filesize / mean
    
    error = stats.sem(df_format["time taken"].to_list())
    #print(f"error: {error}, format: {format}")
    
    tmp = pd.DataFrame(data=[{"error bar": error, "mean time": mean, "format": format, "engine": df_format["engine"].iat[0], "run": df_format["run"].iat[0], "total filesize": df_format["total filesize"].iat[0], "throughput": throughput, "unit":unit}])
    smth = pd.concat([smth, tmp], ignore_index=True)

fig = px.line(
    data_frame=smth, 
    log_y=True, 
    x="total filesize", 
    y="mean time", 
    color="engine", 
    markers=True, 
    hover_data=["format"], 
    labels={"mean time": "mean time in seconds (s)"},
    error_y="error bar",
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-c": '#FFB000',
        "hdf5-c": '#FF4430',
        "zarr-python-parallel": '#AB029E',
        "netcdf4-python-parallel": '#4B0092',
        "hdf5-python-parallel": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )
fig.show()
if save_image: fig.write_image("images/both-line-total-filesize-ser.svg", width=900, height=500, scale=1)

unit = smth["unit"].iat[0]
fig = px.bar(
    data_frame=smth, 
    x="total filesize", 
    y="throughput", 
    color="engine", 
    barmode='group', 
    hover_data=["format"], 
    labels={"throughput": f"throughput in {unit}"},
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-c": '#FFB000',
        "hdf5-c": '#FF4430',
        "zarr-python-parallel": '#AB029E',
        "netcdf4-python-parallel": '#4B0092',
        "hdf5-python-parallel": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )
fig.show()
if save_image: fig.write_image("images/both-box-datarate-ser.svg", width=900, height=500, scale=1)
# Out:
# <div>                            <div id="e191195d-7c7e-4884-9123-f74ed7753be1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e191195d-7c7e-4884-9123-f74ed7753be1")) {                    Plotly.newPlot(                        "e191195d-7c7e-4884-9123-f74ed7753be1",                        [{"customdata":[["zarr-python-[134217728]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[402653184]-[]"]],"error_y":{"array":[0.0037440611257366935,0.002729115566259651,0.038451317337310935]},"hovertemplate":"engine=zarr-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zarr-python","line":{"color":"#56B4E9","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"zarr-python","orientation":"v","showlegend":true,"x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[0.3971505738,0.795594,1.1955305558],"yaxis":"y","type":"scatter"},{"customdata":[["netcdf4-python-[134217728]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[402653184]-[]"]],"error_y":{"array":[0.01624658207219955,0.03219271475936466,0.0882366615592895]},"hovertemplate":"engine=netcdf4-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python","line":{"color":"#4B0092","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"netcdf4-python","orientation":"v","showlegend":true,"x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[0.16347047860000002,0.31432596560000003,0.5542202538],"yaxis":"y","type":"scatter"},{"customdata":[["hdf5-python-[134217728]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[402653184]-[]"]],"error_y":{"array":[0.027118060667090237,0.057580123820578775,0.0945657890004878]},"hovertemplate":"engine=hdf5-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python","line":{"color":"#117733","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"hdf5-python","orientation":"v","showlegend":true,"x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[0.5426631998,1.0450451036000001,1.6807261938],"yaxis":"y","type":"scatter"},{"customdata":[["netcdf4-python-parallel-[134217728]-[]"],["netcdf4-python-parallel-[268435456]-[]"],["netcdf4-python-parallel-[402653184]-[]"]],"error_y":{"array":[0.003555831041790447,0.005384236667483848,0.028880612880835304]},"hovertemplate":"engine=netcdf4-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python-parallel","line":{"color":"#FFB000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"netcdf4-python-parallel","orientation":"v","showlegend":true,"x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[0.07632736180000002,0.163323234,0.2812047526],"yaxis":"y","type":"scatter"},{"customdata":[["hdf5-python-parallel-[134217728]-[]"],["hdf5-python-parallel-[268435456]-[]"],["hdf5-python-parallel-[402653184]-[]"]],"error_y":{"array":[0.0005505480576181696,0.006988609235090105,0.01012909692225805]},"hovertemplate":"engine=hdf5-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python-parallel","line":{"color":"#FF4430","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"hdf5-python-parallel","orientation":"v","showlegend":true,"x":["1.0 GB" ...
# <div>                            <div id="5e242147-cb89-437a-8030-edbbd2859de5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e242147-cb89-437a-8030-edbbd2859de5")) {                    Plotly.newPlot(                        "5e242147-cb89-437a-8030-edbbd2859de5",                        [{"alignmentgroup":"True","customdata":[["zarr-python-[134217728]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[402653184]-[]"]],"hovertemplate":"engine=zarr-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zarr-python","marker":{"color":"#56B4E9","pattern":{"shape":""}},"name":"zarr-python","offsetgroup":"zarr-python","orientation":"v","showlegend":true,"textposition":"auto","x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[2.5179366869140853,2.513845001344907,2.5093461521713456],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["netcdf4-python-[134217728]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[402653184]-[]"]],"hovertemplate":"engine=netcdf4-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python","marker":{"color":"#4B0092","pattern":{"shape":""}},"name":"netcdf4-python","offsetgroup":"netcdf4-python","orientation":"v","showlegend":true,"textposition":"auto","x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[6.117312487026632,6.362821462052322,5.41301040413186],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-python-[134217728]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[402653184]-[]"]],"hovertemplate":"engine=hdf5-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python","marker":{"color":"#117733","pattern":{"shape":""}},"name":"hdf5-python","offsetgroup":"hdf5-python","orientation":"v","showlegend":true,"textposition":"auto","x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[1.8427636153852938,1.9137929962164741,1.784942729557405],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["netcdf4-python-parallel-[134217728]-[]"],["netcdf4-python-parallel-[268435456]-[]"],["netcdf4-python-parallel-[402653184]-[]"]],"hovertemplate":"engine=netcdf4-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python-parallel","marker":{"color":"#FFB000","pattern":{"shape":""}},"name":"netcdf4-python-parallel","offsetgroup":"netcdf4-python-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[13.101461604559216,12.245655140529484,10.66838299232927],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-python-parallel-[134217728]-[]"],["hdf5-python-parallel-[268435456]-[]"],["hdf5-python-parallel-[402653184]-[]"]],"hovertemplate":"engine=hdf5-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python-parallel","marker":{"color":"#FF4430","pattern":{"shape":""}},"name":"hdf5-python-parallel","offsetgroup":"hdf5-python-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[7.394749721190574,7.200761220695625,6.94276818377985],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour", ...
# <div>                            <div id="b8bd0a1b-52b1-4d3f-bf90-0449e9f8839b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8bd0a1b-52b1-4d3f-bf90-0449e9f8839b")) {                    Plotly.newPlot(                        "b8bd0a1b-52b1-4d3f-bf90-0449e9f8839b",                        [{"alignmentgroup":"True","customdata":[["zarr-python-[134217728]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[402653184]-[]"]],"hovertemplate":"engine=%{x}\u003cbr\u003erelative standard deviation (%)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zarr-python","marker":{"color":"#56B4E9"},"name":"zarr-python","notched":false,"offsetgroup":"zarr-python","orientation":"v","showlegend":true,"x":["zarr-python","zarr-python","zarr-python"],"x0":" ","xaxis":"x","y":["1.89%","0.69%","6.43%"],"y0":" ","yaxis":"y","type":"box","boxmean":true},{"alignmentgroup":"True","customdata":[["netcdf4-python-[134217728]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[402653184]-[]"]],"hovertemplate":"engine=%{x}\u003cbr\u003erelative standard deviation (%)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python","marker":{"color":"#4B0092"},"name":"netcdf4-python","notched":false,"offsetgroup":"netcdf4-python","orientation":"v","showlegend":true,"x":["netcdf4-python","netcdf4-python","netcdf4-python"],"x0":" ","xaxis":"x","y":["19.88%","20.48%","31.84%"],"y0":" ","yaxis":"y","type":"box","boxmean":true},{"alignmentgroup":"True","customdata":[["hdf5-python-[134217728]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[402653184]-[]"]],"hovertemplate":"engine=%{x}\u003cbr\u003erelative standard deviation (%)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python","marker":{"color":"#117733"},"name":"hdf5-python","notched":false,"offsetgroup":"hdf5-python","orientation":"v","showlegend":true,"x":["hdf5-python","hdf5-python","hdf5-python"],"x0":" ","xaxis":"x","y":["9.99%","11.02%","11.25%"],"y0":" ","yaxis":"y","type":"box","boxmean":true},{"alignmentgroup":"True","customdata":[["netcdf4-python-parallel-[134217728]-[]"],["netcdf4-python-parallel-[268435456]-[]"],["netcdf4-python-parallel-[402653184]-[]"]],"hovertemplate":"engine=%{x}\u003cbr\u003erelative standard deviation (%)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python-parallel","marker":{"color":"#FFB000"},"name":"netcdf4-python-parallel","notched":false,"offsetgroup":"netcdf4-python-parallel","orientation":"v","showlegend":true,"x":["netcdf4-python-parallel","netcdf4-python-parallel","netcdf4-python-parallel"],"x0":" ","xaxis":"x","y":["9.32%","6.59%","20.54%"],"y0":" ","yaxis":"y","type":"box","boxmean":true},{"alignmentgroup":"True","customdata":[["hdf5-python-parallel-[134217728]-[]"],["hdf5-python-parallel-[268435456]-[]"],["hdf5-python-parallel-[402653184]-[]"]],"hovertemplate":"engine=%{x}\u003cbr\u003erelative standard deviation (%)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python-parallel","marker":{"color":"#FF4430"},"name":"hdf5-python-parallel","notched":false,"offsetgroup":"hdf5-python-parallel","orientation":"v","showlegend":true,"x":["hdf5-python-parallel","hdf5-python-parallel","hdf5-python-parallel"],"x0":" ","xaxis":"x","y":["0.81%","5.03%","4.69%"],"y0":" ","yaxis":"y","type":"box","boxmean":true}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[ ...
# <div>                            <div id="e752bc0c-47e5-4f65-ae48-80337ef459be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e752bc0c-47e5-4f65-ae48-80337ef459be")) {                    Plotly.newPlot(                        "e752bc0c-47e5-4f65-ae48-80337ef459be",                        [{"alignmentgroup":"True","customdata":[["zarr-python-[134217728]-[]"],["zarr-python-[134217728]-[]"],["zarr-python-[134217728]-[]"],["zarr-python-[134217728]-[]"],["zarr-python-[134217728]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[268435456]-[]"],["zarr-python-[402653184]-[]"],["zarr-python-[402653184]-[]"],["zarr-python-[402653184]-[]"],["zarr-python-[402653184]-[]"],["zarr-python-[402653184]-[]"]],"hovertemplate":"engine=zarr-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003etime taken in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zarr-python","marker":{"color":"#56B4E9"},"name":"zarr-python","notched":false,"offsetgroup":"zarr-python","orientation":"v","showlegend":true,"x":["1.0 GB","1.0 GB","1.0 GB","1.0 GB","1.0 GB","2.0 GB","2.0 GB","2.0 GB","2.0 GB","2.0 GB","3.0 GB","3.0 GB","3.0 GB","3.0 GB","3.0 GB"],"x0":" ","xaxis":"x","y":[0.410960726,0.39918484800000004,0.390888595,0.39192502900000004,0.392793671,0.8025223250000001,0.800762352,0.795330865,0.788234612,0.7911198460000001,1.345896439,1.188233725,1.154188991,1.141234052,1.148099572],"y0":" ","yaxis":"y","type":"box","boxmean":true},{"alignmentgroup":"True","customdata":[["netcdf4-python-[134217728]-[]"],["netcdf4-python-[134217728]-[]"],["netcdf4-python-[134217728]-[]"],["netcdf4-python-[134217728]-[]"],["netcdf4-python-[134217728]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[268435456]-[]"],["netcdf4-python-[402653184]-[]"],["netcdf4-python-[402653184]-[]"],["netcdf4-python-[402653184]-[]"],["netcdf4-python-[402653184]-[]"],["netcdf4-python-[402653184]-[]"]],"hovertemplate":"engine=netcdf4-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003etime taken in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python","marker":{"color":"#4B0092"},"name":"netcdf4-python","notched":false,"offsetgroup":"netcdf4-python","orientation":"v","showlegend":true,"x":["1.0 GB","1.0 GB","1.0 GB","1.0 GB","1.0 GB","2.0 GB","2.0 GB","2.0 GB","2.0 GB","2.0 GB","3.0 GB","3.0 GB","3.0 GB","3.0 GB","3.0 GB"],"x0":" ","xaxis":"x","y":[0.167148758,0.225297626,0.138858708,0.143737049,0.142310252,0.32467368300000005,0.436002463,0.27186949600000004,0.270387698,0.268696488,0.7082061270000001,0.822933951,0.42587366400000004,0.40766944200000005,0.40641808500000004],"y0":" ","yaxis":"y","type":"box","boxmean":true},{"alignmentgroup":"True","customdata":[["hdf5-python-[134217728]-[]"],["hdf5-python-[134217728]-[]"],["hdf5-python-[134217728]-[]"],["hdf5-python-[134217728]-[]"],["hdf5-python-[134217728]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[268435456]-[]"],["hdf5-python-[402653184]-[]"],["hdf5-python-[402653184]-[]"],["hdf5-python-[402653184]-[]"],["hdf5-python-[402653184]-[]"],["hdf5-python-[402653184]-[]"]],"hovertemplate":"engine=hdf5-python\u003cbr\u003etotal filesize=%{x}\u003cbr\u003etime taken in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python","marker":{"color":"#117733"},"name":"hdf5-python","notched":false,"offsetgroup":"hdf5-python","orientation" ...
# <div>                            <div id="ba71f4a7-b388-4bd3-b4f9-ee8a81182de3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba71f4a7-b388-4bd3-b4f9-ee8a81182de3")) {                    Plotly.newPlot(                        "ba71f4a7-b388-4bd3-b4f9-ee8a81182de3",                        [{"customdata":[["netcdf4-c-[1342177280]-[]"],["netcdf4-c-[2684354560]-[]"],["netcdf4-c-[4026531840]-[]"],["netcdf4-c-[5368709120]-[]"],["netcdf4-c-[6710886400]-[]"],["netcdf4-c-[8053063680]-[]"]],"error_y":{"array":[0.20260643020827326,0.10475595690059802,0.9241448213408976,74.03824636870172,5.039099372239831,455.37301781427556]},"hovertemplate":"engine=netcdf4-c\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-c","line":{"color":"#4B0092","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"netcdf4-c","orientation":"v","showlegend":true,"x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB"],"xaxis":"x","y":[12.9780552,28.295209600000003,47.102517999999996,340.81968,87.5785664,839.433229],"yaxis":"y","type":"scatter"},{"customdata":[["hdf5-c-[1342177280]-[]"],["hdf5-c-[2684354560]-[]"],["hdf5-c-[4026531840]-[]"],["hdf5-c-[5368709120]-[]"],["hdf5-c-[6710886400]-[]"],["hdf5-c-[8053063680]-[]"]],"error_y":{"array":[0.03228160025711239,0.238760022666149,0.7034292376161229,0.648478293606625,1.2095436011528728,1.7018072719199027]},"hovertemplate":"engine=hdf5-c\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-c","line":{"color":"#117733","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"hdf5-c","orientation":"v","showlegend":true,"x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB"],"xaxis":"x","y":[5.6535556,11.7441148,19.100969999999997,27.560476599999998,37.411510400000004,45.628243399999995],"yaxis":"y","type":"scatter"},{"customdata":[["netcdf4-c-parallel-[1342177280]-[]"],["netcdf4-c-parallel-[2684354560]-[]"],["netcdf4-c-parallel-[4026531840]-[]"],["netcdf4-c-parallel-[5368709120]-[]"],["netcdf4-c-parallel-[6710886400]-[]"],["netcdf4-c-parallel-[8053063680]-[]"]],"error_y":{"array":[0.048910694309118145,0.019981896950490012,0.13502595117887517,0.28295429098541697,0.39541375977942406,0.3159829473245989]},"hovertemplate":"engine=netcdf4-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-c-parallel","line":{"color":"#FFB000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"netcdf4-c-parallel","orientation":"v","showlegend":true,"x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB"],"xaxis":"x","y":[2.8482200000000004,5.1163152,11.8138134,16.4676456,23.176942999999998,29.491021800000006],"yaxis":"y","type":"scatter"},{"customdata":[["hdf5-c-parallel-[1342177280]-0"],["hdf5-c-parallel-[2684354560]-0"],["hdf5-c-parallel-[4026531840]-0"],["hdf5-c-parallel-[5368709120]-0"],["hdf5-c-parallel-[6710886400]-0"],["hdf5-c-parallel-[8053063680]-0"]],"error_y":{"array":[0.09168068240616452,0.014712477963959742,0.18467140087880435,0.22528399385162728,0.3900060039812721,0.15705902270847077]},"hovertemplate":"engine=hdf5-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-c-parallel","line":{"color":"#FF4430","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"hdf5-c-parallel","o ...
# <div>                            <div id="1561f388-8d34-42a2-b74b-c945a78b6acc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1561f388-8d34-42a2-b74b-c945a78b6acc")) {                    Plotly.newPlot(                        "1561f388-8d34-42a2-b74b-c945a78b6acc",                        [{"alignmentgroup":"True","customdata":[["netcdf4-c-[1342177280]-[]"],["netcdf4-c-[2684354560]-[]"],["netcdf4-c-[4026531840]-[]"],["netcdf4-c-[5368709120]-[]"],["netcdf4-c-[6710886400]-[]"],["netcdf4-c-[8053063680]-[]"]],"hovertemplate":"engine=netcdf4-c\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-c","marker":{"color":"#4B0092","pattern":{"shape":""}},"name":"netcdf4-c","offsetgroup":"netcdf4-c","orientation":"v","showlegend":true,"textposition":"auto","x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB"],"xaxis":"x","y":[0.7705314737758243,0.7068334280867103,0.6369086255643489,0.11736411465441197,0.5709159450228224,0.07147679878181235],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-c-[1342177280]-[]"],["hdf5-c-[2684354560]-[]"],["hdf5-c-[4026531840]-[]"],["hdf5-c-[5368709120]-[]"],["hdf5-c-[6710886400]-[]"],["hdf5-c-[8053063680]-[]"]],"hovertemplate":"engine=hdf5-c\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-c","marker":{"color":"#117733","pattern":{"shape":""}},"name":"hdf5-c","offsetgroup":"hdf5-c","orientation":"v","showlegend":true,"textposition":"auto","x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB"],"xaxis":"x","y":[1.768798382384353,1.7029806282206983,1.5706008647728364,1.4513537113505506,1.3364870721712425,1.314975013918682],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["netcdf4-c-parallel-[1342177280]-[]"],["netcdf4-c-parallel-[2684354560]-[]"],["netcdf4-c-parallel-[4026531840]-[]"],["netcdf4-c-parallel-[5368709120]-[]"],["netcdf4-c-parallel-[6710886400]-[]"],["netcdf4-c-parallel-[8053063680]-[]"]],"hovertemplate":"engine=netcdf4-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-c-parallel","marker":{"color":"#FFB000","pattern":{"shape":""}},"name":"netcdf4-c-parallel","offsetgroup":"netcdf4-c-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB"],"xaxis":"x","y":[3.5109647428920514,3.909063303996595,2.5394001906276933,2.429005394675241,2.157316432973926,2.034517501865601],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-c-parallel-[1342177280]-0"],["hdf5-c-parallel-[2684354560]-0"],["hdf5-c-parallel-[4026531840]-0"],["hdf5-c-parallel-[5368709120]-0"],["hdf5-c-parallel-[6710886400]-0"],["hdf5-c-parallel-[8053063680]-0"]],"hovertemplate":"engine=hdf5-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-c-parallel","marker":{"color":"#FF4430","pattern":{"shape":""}},"name":"hdf5-c-parallel","offsetgroup":"hdf5-c-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB"],"xaxis":"x","y":[5.088948716831759,5.62660425037061,2.931073978138213,2.8089070611443314,2.8642676492678145,2.8562830071469243],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-async-[1342177280]-0"],["hdf5-async-[2684354560]-0"],["hdf5-async-[40 ...
# <div>                            <div id="1b3aa040-7905-4123-a08d-25724043b169" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b3aa040-7905-4123-a08d-25724043b169")) {                    Plotly.newPlot(                        "1b3aa040-7905-4123-a08d-25724043b169",                        [{"customdata":[["netcdf4-python-parallel-[134217728]-[]"],["netcdf4-python-parallel-[268435456]-[]"],["netcdf4-python-parallel-[402653184]-[]"]],"error_y":{"array":[0.003555831041790447,0.005384236667483848,0.028880612880835304]},"hovertemplate":"engine=netcdf4-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python-parallel","line":{"color":"#4B0092","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"netcdf4-python-parallel","orientation":"v","showlegend":true,"x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[0.07632736180000002,0.163323234,0.2812047526],"yaxis":"y","type":"scatter"},{"customdata":[["hdf5-python-parallel-[134217728]-[]"],["hdf5-python-parallel-[268435456]-[]"],["hdf5-python-parallel-[402653184]-[]"]],"error_y":{"array":[0.0005505480576181696,0.006988609235090105,0.01012909692225805]},"hovertemplate":"engine=hdf5-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python-parallel","line":{"color":"#117733","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"hdf5-python-parallel","orientation":"v","showlegend":true,"x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[0.13523108120000002,0.27774841279999996,0.43210430200000005],"yaxis":"y","type":"scatter"},{"customdata":[["netcdf4-c-parallel-[1342177280]-[]"],["netcdf4-c-parallel-[2684354560]-[]"],["netcdf4-c-parallel-[4026531840]-[]"],["netcdf4-c-parallel-[5368709120]-[]"],["netcdf4-c-parallel-[6710886400]-[]"],["netcdf4-c-parallel-[8053063680]-[]"],["netcdf4-c-parallel-[9395240960]-[]"]],"error_y":{"array":[0.039279376631509835,0.010812654994958384,0.188280429834489,0.1230579963682167,0.3250846173518522,0.3122666526578844,0.61224976016193]},"hovertemplate":"engine=netcdf4-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-c-parallel","line":{"color":"#FFB000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"netcdf4-c-parallel","orientation":"v","showlegend":true,"x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB","70.0 GB"],"xaxis":"x","y":[3.0557554,5.2840018,12.0303544,16.8785944,22.712773,30.4320006,35.129302800000005],"yaxis":"y","type":"scatter"},{"customdata":[["hdf5-c-parallel-[1342177280]-0"],["hdf5-c-parallel-[2684354560]-0"],["hdf5-c-parallel-[4026531840]-0"],["hdf5-c-parallel-[5368709120]-0"],["hdf5-c-parallel-[6710886400]-0"],["hdf5-c-parallel-[8053063680]-0"],["hdf5-c-parallel-[9395240960]-0"]],"error_y":{"array":[0.049309649943393465,0.3338492791048979,0.07505431397221617,0.21610828153520634,0.27723742606412305,0.24705245041824594,0.41517016478432034]},"hovertemplate":"engine=hdf5-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003emean time in seconds (s)=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-c-parallel","line":{"color":"#FF4430","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"hdf5-c-parallel","orientation":"v","showlegend":true,"x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB","70.0 GB"],"xaxis":"x","y":[2.0421772000 ...
# <div>                            <div id="bd1f3061-8d37-4222-a2f4-cc5c6a0e8a26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd1f3061-8d37-4222-a2f4-cc5c6a0e8a26")) {                    Plotly.newPlot(                        "bd1f3061-8d37-4222-a2f4-cc5c6a0e8a26",                        [{"alignmentgroup":"True","customdata":[["netcdf4-python-parallel-[134217728]-[]"],["netcdf4-python-parallel-[268435456]-[]"],["netcdf4-python-parallel-[402653184]-[]"]],"hovertemplate":"engine=netcdf4-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-python-parallel","marker":{"color":"#4B0092","pattern":{"shape":""}},"name":"netcdf4-python-parallel","offsetgroup":"netcdf4-python-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[13.101461604559216,12.245655140529484,10.66838299232927],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-python-parallel-[134217728]-[]"],["hdf5-python-parallel-[268435456]-[]"],["hdf5-python-parallel-[402653184]-[]"]],"hovertemplate":"engine=hdf5-python-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-python-parallel","marker":{"color":"#117733","pattern":{"shape":""}},"name":"hdf5-python-parallel","offsetgroup":"hdf5-python-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["1.0 GB","2.0 GB","3.0 GB"],"xaxis":"x","y":[7.394749721190574,7.200761220695625,6.94276818377985],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["netcdf4-c-parallel-[1342177280]-[]"],["netcdf4-c-parallel-[2684354560]-[]"],["netcdf4-c-parallel-[4026531840]-[]"],["netcdf4-c-parallel-[5368709120]-[]"],["netcdf4-c-parallel-[6710886400]-[]"],["netcdf4-c-parallel-[8053063680]-[]"],["netcdf4-c-parallel-[9395240960]-[]"]],"hovertemplate":"engine=netcdf4-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"netcdf4-c-parallel","marker":{"color":"#FFB000","pattern":{"shape":""}},"name":"netcdf4-c-parallel","offsetgroup":"netcdf4-c-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB","70.0 GB"],"xaxis":"x","y":[3.2725132384614293,3.7850100656665178,2.4936921226526794,2.369865585489749,2.2014044696347734,1.9716087939351579,1.9926384647747688],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-c-parallel-[1342177280]-0"],["hdf5-c-parallel-[2684354560]-0"],["hdf5-c-parallel-[4026531840]-0"],["hdf5-c-parallel-[5368709120]-0"],["hdf5-c-parallel-[6710886400]-0"],["hdf5-c-parallel-[8053063680]-0"],["hdf5-c-parallel-[9395240960]-0"]],"hovertemplate":"engine=hdf5-c-parallel\u003cbr\u003etotal filesize=%{x}\u003cbr\u003ethroughput in GB\u002fs=%{y}\u003cbr\u003eformat=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"hdf5-c-parallel","marker":{"color":"#FF4430","pattern":{"shape":""}},"name":"hdf5-c-parallel","offsetgroup":"hdf5-c-parallel","orientation":"v","showlegend":true,"textposition":"auto","x":["10.0 GB","20.0 GB","30.0 GB","40.0 GB","50.0 GB","60.0 GB","70.0 GB"],"xaxis":"x","y":[4.896734720180011,5.0009284223616115,2.87192594551317,2.7802236022634355,2.8521591734816916,2.7802160787643375,2.6628168117685],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["hdf5-async-[1342177280]-0"],["hdf5-async-[2684354560]-0"],["hdf5-async-[4026531840]-0"],["hdf5-async-[53687 ...

# %%
#%%script false --no-raise-error
import pandas as pd

df_bench_c = pd.read_json("data/plotting/plotting_bench_c_chunks.json")
df_bench_c_copy = pd.read_json("data/plotting/plotting_bench_c.json")
df_bench_python = pd.read_json("data/plotting/plotting_bench_python_chunks.json")
df_bench_python_copy = pd.read_json("data/plotting/plotting_bench_python copy.json")

# %%
import plotly.express as px 
import numpy as np
from scipy import stats

df = df_bench_python

save_image = False

# python plotting

df = df[~df["engine"].isin(["zarr-python", "netcdf4-python", "hdf5-python"])]

# plot development in time taken by chunksize
filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    mean =  np.mean(df_format["time taken"].to_list())
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])
    unit = f"{str_filesize.split()[1]}/s"

    throughput = filesize / mean
    
    error = stats.sem(df_format["time taken"].to_list())
    
    tmp = pd.DataFrame(data=[{"error bar": error, "mean time": mean, "format": format, "engine": df_format["engine"].iat[0], "run": df_format["run"].iat[0], "total filesize": df_format["total filesize"].iat[0], "throughput": throughput, "unit":unit, "filesize per chunk": df_format["filesize per chunk"].iat[0]}])
    smth = pd.concat([smth, tmp], ignore_index=True)
    


fig = px.line(
    data_frame=smth, 
    log_y=True, 
    x="filesize per chunk", 
    y="mean time", 
    color="engine", 
    markers=True, 
    hover_data=["format"], 
    labels={"mean time": "mean time in seconds (s)"},
    error_y="error bar",
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-python-parallel": '#FFB000',
        "hdf5-python-parallel": '#FF4430',
    },
    )
fig.show()
if save_image: fig.write_image("images/python-line-total-filesize-chunks-par.svg", width=900, height=500, scale=1)

unit = smth["unit"].iat[0]
fig = px.bar(
    data_frame=smth,
    x="filesize per chunk", 
    y="throughput", 
    color="engine", 
    barmode='group', 
    hover_data=["format"], 
    labels={"throughput": f"throughput in {unit}"},
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-python-parallel": '#FFB000',
        "hdf5-python-parallel": '#FF4430',
    },
    )
fig.show()
if save_image: fig.write_image("images/python-box-datarate-chunks-par.svg", width=900, height=500, scale=1)



######################################################################################################################################################################################
######################################################################################################################################################################################
######################################################################################################################################################################################
######################################################################################################################################################################################
######################################################################################################################################################################################



df = df_bench_c

df = df[~df["engine"].isin(["hdf5-subfiling", "hdf5-async", "hdf5-c-parallel", "netcdf4-c-parallel"])]

# c plotting

save_image = False

# plot development in time taken by chunksize
filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    mean =  np.mean(df_format["time taken"].to_list())
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])
    unit = f"{str_filesize.split()[1]}/s"

    throughput = filesize / mean
    
    error = stats.sem(df_format["time taken"].to_list())
    
    tmp = pd.DataFrame(data=[{"error bar": error, "mean time": mean, "format": format, "engine": df_format["engine"].iat[0], "run": df_format["run"].iat[0], "total filesize": df_format["total filesize"].iat[0], "throughput": throughput, "unit":unit, "filesize per chunk": df_format["filesize per chunk"].iat[0]}])
    smth = pd.concat([smth, tmp], ignore_index=True)

fig = px.line(
    data_frame=smth, 
    log_y=True, 
    x="filesize per chunk", 
    y="mean time", 
    color="engine", 
    markers=True, 
    hover_data=["format"], 
    labels={"mean time": "mean time in seconds (s)"},
    error_y="error bar",
    color_discrete_map={
        "netcdf4-c": '#4B0092',
        "hdf5-c": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )
fig.show()
if save_image: fig.write_image("images/c-line-total-filesize-chunks-ser.svg", width=900, height=500, scale=1)

unit = smth["unit"].iat[0]
fig = px.bar(
    data_frame=smth, 
    x="filesize per chunk", 
    y="throughput", 
    color="engine", 
    barmode='group', 
    hover_data=["format"], 
    labels={"throughput": f"throughput in {unit}"},
    color_discrete_map={
        "netcdf4-c": '#4B0092',
        "hdf5-c": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )
fig.show()
if save_image: fig.write_image("images/c-box-datarate-chunks-ser.svg", width=900, height=500, scale=1)


save_image = False


df = df_bench_both = pd.concat([df_bench_python, df_bench_c], ignore_index=True)

df = df[~df["engine"].isin(["netcdf4-python-parallel", "hdf5-python-parallel", "hdf5-subfiling", "hdf5-async", "hdf5-c-parallel", "netcdf4-c-parallel"])]

# plotting both

# plot development in time taken by chunksize
filter = df["format"].drop_duplicates(ignore_index=True)
smth = pd.DataFrame()
for format in filter:
    mask = df["format"].values == format
    df_format = df[mask]
    
    mean =  np.mean(df_format["time taken"].to_list())
    str_filesize = df_format["total filesize"].iat[0]
    filesize = float(str_filesize.split()[0])
    unit = f"{str_filesize.split()[1]}/s"

    throughput = filesize / mean
    
    error = stats.sem(df_format["time taken"].to_list())
    
    tmp = pd.DataFrame(data=[{"error bar": error, "mean time": mean, "format": format, "engine": df_format["engine"].iat[0], "run": df_format["run"].iat[0], "total filesize": df_format["total filesize"].iat[0], "throughput": throughput, "unit":unit, "filesize per chunk": df_format["filesize per chunk"].iat[0]}])
    smth = pd.concat([smth, tmp], ignore_index=True)

fig = px.line(
    data_frame=smth, 
    log_y=True, 
    x="filesize per chunk", 
    y="mean time", 
    color="engine", 
    markers=True, 
    hover_data=["format"], 
    labels={"mean time": "mean time in seconds (s)"},
    error_y="error bar",
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-c": '#FFB000',
        "hdf5-c": '#FF4430',
        "netcdf4-python-parallel": '#4B0092',
        "hdf5-python-parallel": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )
fig.show()
if save_image: fig.write_image("images/both-line-total-filesize-chunks-par.svg", width=900, height=500, scale=1)

unit = smth["unit"].iat[0]
fig = px.bar(
    data_frame=smth, 
    x="filesize per chunk", 
    y="throughput", 
    color="engine", 
    barmode='group', 
    hover_data=["format"], 
    labels={"throughput": f"throughput in {unit}"},
    color_discrete_map={
        "zarr-python": '#56B4E9',
        "netcdf4-python": '#4B0092',
        "hdf5-python": '#117733',
        "netcdf4-c": '#FFB000',
        "hdf5-c": '#FF4430',
        "netcdf4-python-parallel": '#4B0092',
        "hdf5-python-parallel": '#117733',
        "netcdf4-c-parallel": '#FFB000',
        "hdf5-c-parallel": '#FF4430',
        "hdf5-async": '#56B4E9',
        "hdf5-subfiling": '#AB029E',
    },
    )
fig.show()
if save_image: fig.write_image("images/both-box-datarate-chunks-par.svg", width=900, height=500, scale=1)

# %%
# plot runs by engine
fig = px.box(data_frame=df, log_y=True, x="engine", y="time taken", color="run", hover_data=["format", "filesize per chunk"])
fig.show()

# plot formats by chunksize
fig = px.box(data_frame=df, log_y=True, x="total filesize", y="time taken", color="engine", hover_data=["format", "filesize per chunk"], title="total filesize")
fig.show()

filter = df["engine"].drop_duplicates(ignore_index=True)

for engine in filter:
    
    mask = df["engine"].values == engine
    df_engine = df[mask]
    fig =  fig = px.box(data_frame=df_engine, log_y=True, x="engine", y="time taken", color="total filesize",)
    fig.show()


filter = df["run"].drop_duplicates(ignore_index=True)

fig = px.violin(data_frame=df, log_x=True, x="time taken", y="format", color="engine")
fig.show()

for engine in filter:
    
    mask = df["run"].values == engine
    fig = px.box(data_frame=df[mask], log_y=True, x="engine", y="time taken", color="total filesize", points="all",)
    #fig.show()
    
    fig = px.violin(data_frame=df[mask], log_x=True, x="time taken", y="total filesize", color="engine")
    fig.show()
